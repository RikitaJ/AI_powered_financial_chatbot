# %%
# !pip install openpyxl pandas

import pandas as pd

# %%
data = pd.read_excel('gen ai.xlsx')

# %%
data.head(9)
# Out:
#    years    company  total revenue  net income  Total Assets  \
# 0   2023  microsoft         211.92      72.360       411.982
# 1   2022  microsoft         198.30      72.700       364.800
# 2   2021  microsoft         168.10      61.300       333.800
# 3   2023      tesla          96.77      14.997       100.340
# 4   2022      tesla          81.46      12.556        82.340
# 5   2021      tesla          53.82       5.519        62.130
# 6   2023      apple         383.29      99.800       352.580
# 7   2022      apple         394.33      99.800       352.760
# 8   2021     apple          365.82      94.680       351.000
#
#    Total Liabilities  Cash Flow
# 0             205.75     87.580
# 1             198.30     89.000
# 2             191.80     76.700
# 3              34.54      4.357
# 4              30.33      7.561
# 5              27.11      4.983
# 6             263.22     90.130
# 7             302.08    111.440
# 8             287.91    104.040

# %%
# Perform basic analysis on the financial data
def analyze_data(data):
    summary = data.describe()
    return summary

# %%
# Load the Excel sheet
def load_data(file_path):
    try:
        data = pd.read_excel('gen ai.xlsx')
        return data
    except Exception as e:
        return str(e)

# %%
def chatbot():
    print("Hello! I'm your financial data analysis bot.")
    print("Please upload your financial Excel sheet.")
    print("What would you like to know")


    while True:
        user_input = input("Enter your chat: ")

        if user_input == "Summary of the data":
            summary = analyze_data(data)
            print("Here's the summary of your data:")
            print(summary)

        elif user_input == "Specific column analysis":
            column = input("Enter the column name you want to analyze: ")
            if column in data.columns:
                print(data[column].describe())
            else:
                print(f"Column {column} does not exist in the data.")

        elif user_input == "Exit":
            print("Goodbye!")

        elif user_input == "What companies are we looking at?":
            print("This spreadsheet shows information about well-known businesses like Microsoft, Tesla, and Apple.")

        elif user_input == "What kind of information does it show":
            print("We can see details about how these companies performed financially over the past few years (2021, 2022, 2023).")

        elif user_input == "What's the difference between revenue and net income":
            print("Revenue is the total amount of money a company makes from selling its products or services. Net income, sometimes called profit, is the money left over after a company pays all its expenses.")

        elif user_input == "What kind of information does it show":
            print("We can see details about how these companies performed financially over the past few years (2021, 2022, 2023).")

        elif user_input == "What are total assets and liabilities" :
            print("Imagine assets are everything a company owns, like buildings, equipment, and money in the bank. Liabilities are how much money the company owes to others, like loans or unpaid bills.")


        elif user_input == "How much money did each company bring in during 2023" :
            print("This tells us how much each company sold in a year.")

        elif user_input == "Did any company make more money in 2023 than in 2022":
            print("This helps us see if a company's sales are growing.")

        elif user_input == "Which company earned more profit in 2022":
            print("Profit shows how much money a company keeps after paying its bills.")

        elif user_input == "Did Apple have more stuff (assets) than Microsoft in 2021?":
            print("This compares the value of everything each company owns.")

        elif user_input == "Has a company been making more or less money over the past three years?":
            print("This shows if a company's sales are going up or down.")

        elif user_input == "Did the value of Apple's things (assets) change from 2021 to 2023?":
            print(" This helps us see if a company's overall value is increasing.")

        elif user_input == "Debt-to-equity ratio":
            print(" Imagine it as a way to see if a company owes a lot of money (debt) compared to the money owners invested (equity). A high ratio might indicate a riskier situation.")

        elif user_input == "Profit margin":
            print("This shows what percentage of a company's revenue is left as profit after expenses. A higher margin means the company keeps more money from each sale.")
            break

def analyze_data(data):
    while True:
        user_input = int(input("Please choose an option:\n1. View data summary\n2. View data distribution\n3. Exit\n"))
        if user_input == 'Summary of the data':
            # Code to view data summary
            break
        elif user_input == 'Specific column analysis':
            # Code to view data distribution
            break

        elif user_input == "What companies are we looking at?":
          break
        elif user_input == "Profit margin":
          break
        elif user_input == 'Exit':
          break
        elif user_input == "Debt-to-equity ratio":
          break
        elif user_input == "Did the value of Apple's things (assets) change from 2021 to 2023?":
          break
        elif user_input == "Has a company been making more or less money over the past three years?":
          break
        elif user_input == "Did Apple have more stuff (assets) than Microsoft in 2021?":
          break
        elif user_input == "Exit":
          break


        else:
           print("Invalid input")

# %%
chatbot()
# Out:
# Hello! I'm your financial data analysis bot.
# Please upload your financial Excel sheet.
# What would you like to know
