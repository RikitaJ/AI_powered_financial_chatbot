# %%
import pandas as pd

# %%
df = pd.read_excel('gen ai.xlsx')

# %%
df['Revenue Growth (%)'] = df.groupby('company')['total revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby('company')['net income'].pct_change() * 100

# %%
df.head(9)
# Out:
#    years    company  total revenue  net income  Total Assets  \
# 0   2023  microsoft         211.92      72.360       411.982
# 1   2022  microsoft         198.30      72.700       364.800
# 2   2021  microsoft         168.10      61.300       333.800
# 3   2023      tesla          96.77      14.997       100.340
# 4   2022      tesla          81.46      12.556        82.340
# 5   2021      tesla          53.82       5.519        62.130
# 6   2023      apple         383.29      99.800       352.580
# 7   2022      apple         394.33      99.800       352.760
# 8   2021     apple          365.82      94.680       351.000
#
#    Total Liabilities  Cash Flow  Revenue Growth (%)  Net Income Growth (%)
# 0             205.75     87.580                 NaN                    NaN
# 1             198.30     89.000           -6.426954               0.469873
# 2             191.80     76.700          -15.229450             -15.680880
# 3              34.54      4.357                 NaN                    NaN
# 4              30.33      7.561          -15.821019             -16.276589
# 5              27.11      4.983          -33.930764             -56.044919
# 6             263.22     90.130                 NaN                    NaN
# 7             302.08    111.440            2.880326               0.000000
# 8             287.91    104.040                 NaN                    NaN

# %% [markdown]
# #Fill NA values that result from pct_change calculations with 0 or an appropriate value

# %%
df.fillna(0, inplace=True)

# %%
df.head(9)
# Out:
#    years    company  total revenue  net income  Total Assets  \
# 0   2023  microsoft         211.92      72.360       411.982
# 1   2022  microsoft         198.30      72.700       364.800
# 2   2021  microsoft         168.10      61.300       333.800
# 3   2023      tesla          96.77      14.997       100.340
# 4   2022      tesla          81.46      12.556        82.340
# 5   2021      tesla          53.82       5.519        62.130
# 6   2023      apple         383.29      99.800       352.580
# 7   2022      apple         394.33      99.800       352.760
# 8   2021     apple          365.82      94.680       351.000
#
#    Total Liabilities  Cash Flow  Revenue Growth (%)  Net Income Growth (%)
# 0             205.75     87.580            0.000000               0.000000
# 1             198.30     89.000           -6.426954               0.469873
# 2             191.80     76.700          -15.229450             -15.680880
# 3              34.54      4.357            0.000000               0.000000
# 4              30.33      7.561          -15.821019             -16.276589
# 5              27.11      4.983          -33.930764             -56.044919
# 6             263.22     90.130            0.000000               0.000000
# 7             302.08    111.440            2.880326               0.000000
# 8             287.91    104.040            0.000000               0.000000

# %% [markdown]
# # summarizing these findings for each company

# %%
summary = df.groupby('company').agg({
    'Revenue Growth (%)': 'mean',
    'Net Income Growth (%)': 'mean'
}).reset_index()

# %%
print("\nYear-over-Year Average Growth Rates (%):")
print(summary)
# Out:
# Year-over-Year Average Growth Rates (%):
#      company  Revenue Growth (%)  Net Income Growth (%)
# 0      apple            1.440163               0.000000
# 1     apple             0.000000               0.000000
# 2  microsoft           -7.218801              -5.070336
# 3      tesla          -16.583927             -24.107169
